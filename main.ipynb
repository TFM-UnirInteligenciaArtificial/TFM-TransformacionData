# %%
import pandas as pd

# %%
# Cargar CSV usando raw string para evitar errores de escape de rutas en Windows
data = pd.read_csv(r"C:\Users\User\Documents\TFMDesarrollo\evtx_csv_output\Aplicacion web1ap 09112025.csv")

# %%
data.head(5)
# Out:
#                     TimeCreated                    ProviderName  EventID  \
# 0  2025-11-10T00:31:00.8223721Z        IIS AspNetCore Module V2     1032
# 1  2025-11-10T00:26:29.4790518Z  Microsoft-Windows-Security-SPP    16384
# 2  2025-11-10T00:26:04.4165436Z        IIS AspNetCore Module V2     1033
# 3  2025-11-10T00:26:02.3837438Z                      edgeupdate        0
# 4  2025-11-10T00:25:58.9971730Z  Microsoft-Windows-Security-SPP    16394
#
#    Level  Task          Keywords               Computer  RecordId  \
# 0      4     0  0x80000000000000  WEB1AP.solinet.int.co       NaN
# 1      4     0  0x80000000000000  WEB1AP.solinet.int.co       NaN
# 2      4     0  0x80000000000000  WEB1AP.solinet.int.co       NaN
# 3      4     0  0x80000000000000  WEB1AP.solinet.int.co       NaN
# 4      4     0  0x80000000000000  WEB1AP.solinet.int.co       NaN
#
#                                              Message  \
# 0  Application 'E:\Internet\WAPIPDP\' started suc...
# ...

# %%
import pandas as pd
import glob

# Ruta donde están los CSV (por ejemplo, en la carpeta 'data')
ruta = "./evtx_csv_output/*.csv"

# Cargar todos los CSV en una lista de DataFrames
dataframes = [pd.read_csv(archivo) for archivo in glob.glob(ruta)]

# Mostrar cuántos archivos se cargaron
print(f"Se cargaron {len(dataframes)} archivos CSV.")
# Out:
# Se cargaron 9 archivos CSV.

# %%
total= [len(total) for total in dataframes]

# %%
total
# Out:
# [21656, 55847, 216934, 2065, 34534, 21474, 53706, 74173, 59733]

# %%
suma = sum(total)

# %%
suma
# Out:
# 540122
# El kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior.
#
# Revise el código de las celdas para identificar una posible causa del error.
#
# Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información.
#
# Vea Jupyter <a href='command:jupyter.viewOutput'>log</a> para obtener más detalles.
